# %% [markdown]
# # Libraries

# %%
import sys
dabs_ms_dir = r"DABS-MS-Network"
sys.path.append(dabs_ms_dir)

import numpy as np
import torch
from learner import Learner
import random
import os
import pickle
import matplotlib.pyplot as plt

#this should seed them globally to reduce variability
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
pass

# %% [markdown]
# # Data Preprocessing and Structure
# ### Preprocessing
# DABS-MS expects that
# - All the training/validation/testing images are affinely registered to the atlas image.
# - The dimension and voxel size is constant in all 3 dimensions, though the actual value is configurable.
# - The training/validation/testing/gt images are raw image files written with a byte order of 'F' (Fortran-style order), with a float32/single datatype
# - The atlas image has a corresponding mask, mesh, and distance map
#   - The image, mask, and distance map should be .nrrd files
#   - The mesh is a Mesh class, defined in DABS-MS-Network/parser.py
# - All the masks (atlas/gt) are binary masks with black = 0 and white = 255
# - All the images are scaled such that the min is around 0 and the max is around 1 (doesn't have to be exact)
#   - If there is any "out of bounds" areas that happen due to the affine registration and cropping issues, fill them in with the mean value of the rest of the image
#
# DABS-MS has the following optional inputs
# - For each case, if there's an area in of the image that you want excluded from the metrics, you can supply Out-Of-Bounds (oob) masks to indicate that area
# - For the MS term, if you'd like to use a different atlas mask than you're using for evaluation and the weighted gradient term, you can supply it as well using the path_params/ms_atlas_filename section of the parameter dictionary
#
# ### File Structure
# DABS-MS expects that each training/validation/testing case has a unique patient ID, also called a "keyword". It expects that there's a file where the keywords are listed, in three sections separated by double newlines, for training/validation/testing respectively. For example:
#
# train_keyword1<br>
# train_keyword2<br>
# train_keyword3<br>
#
# valid_keyword1<br>
# valid_keyword2<br>
# valid_keyword3<br>
#
# test_keyword1<br>
# test_keyword2<br>
# test_keyword3<br>
#
# It also expects that there's an image directory, ground truth directory, and (optionally) a out-of-bounds directory, with files following a consistent structure. These structures can be defined in the img_template, gt_template, and oob_template sections of the parameter dictionary.

# %% [markdown]
# # Parameter Dictionary

# %%
dataset = "IAC"

params = {}

params["training_params"] = {}
params["training_params"]["batch_size"] = 5
params["training_params"]["epochs"] = 200
params["training_params"]["dim"] = (64, 64, 64)
params["training_params"]["sz"] = (0.3, 0.3, 0.3)
params["training_params"]["device"] = "cuda"

params["path_params"] = {}
params["path_params"]["keyword_filename"]        = r"D:\Project_Data\DATA\IAC\info\keywords.txt" #a list of all patient IDs, separated into training, validation, and testing chunks by double newlines
params["path_params"]["progress_dir"]            = "output"

#these are the paths for the data, where %s will get replaced with the patient ID
params["path_params"]["img_dir"]                 = r"D:\Project_Data\DATA\IAC\img_mean" #where the images are
params["path_params"]["gt_dir"]                  = r"D:\Project_Data\DATA\IAC\gt" #where the ground truth is
params["path_params"]["oob_dir"]                  = r"D:\Project_Data\DATA\IAC\oob" #Out-of-bounds masks for the ground truths: not every dataset will have this, can leave blank
params["path_params"]["img_template"]            = "%s_scaled_mean_filled_img.im" #how the image filenames are formatted in the image dir
params["path_params"]["gt_template"]            = "%s_standardized_msk.im" #how the gt filenames are formatted
params["path_params"]["oob_template"]            = "%s_oob_mask.im" #how the oob filenames are formatted
#atlas
params["path_params"]["atlas_im_filename"]       = r"D:\Project_Data\DATA\IAC\atlas\alt_personal_comp\atlas_scaled_mean_filled_img.nrrd" #the atlas CT image
params["path_params"]["atlas_mesh_filename"]     = r"D:\Project_Data\DATA\IAC\atlas\alt_personal_comp\atlas_standardized_mesh.mesh" #the atlas mesh
params["path_params"]["atlas_mask_filename"]     = r"D:\Project_Data\DATA\IAC\atlas\alt_personal_comp\atlas_standardized_msk.nrrd" #the atlas mask
params["path_params"]["ms_atlas_filename"]       = r"D:\Project_Data\DATA\IAC\atlas\alt_personal_comp\levelset_atlas_mask.nrrd" #if using a modified atlas mask for the mumford shah term, put the filename here. else make an empty string
params["path_params"]["atlas_dist_filename"]     = r"D:\Project_Data\DATA\IAC\atlas\alt_personal_comp\atlas_standardized_dst.nrrd" #a distance transform of the atlas in mm

#losses
params["losses"] = {}
params["losses"]["cross_correlation"] = {"filename":"losses.cross_correlation_loss", "weight": 1.0}
params["losses"]["gradient"]          = {"filename":"losses.gradient_loss",          "weight": 0.5} #recommended: don't use both gradients at the same time
params["losses"]["weighted_gradient"] = {"filename":"losses.weighted_gradient_loss", "weight": 0.0}
params["losses"]["mumford_shah"]      = {"filename":"losses.mumford_shah_loss",      "weight": 0.5}

#debug
params["debug_params"] = {}
params["debug_params"]["verbose"] = False

# %% [markdown]
# # Use the Learner
# **The "learner" is an object which handles all of the network's training, testing, etc. The goal is to separate the "input" and "processing" as much as possible, for maximal versatility**

# %%
lrnr = Learner(params, "DABS-MS-Example", verbose_learner = True)
# Out:
# Loading parameters...
# Making destination directories...
# Loading global values...
# Loading model...
# Making dataloaders...

# %% [markdown]
# **It has a built in train function...**

# %%
lrnr.train()
# Out:
# Starting training...
# Epoch 1/200:
# Epoch:  1 , train: 0.22891380956451723 , valid: 0.19244959205389023
# Saving model...
# 	completed in 41.07059097290039 seconds
# Epoch 2/200:
# Epoch:  2 , train: 0.1780596963970241 , valid: 0.1561297457665205
# Saving model...
# 	completed in 39.26137566566467 seconds
# Epoch 3/200:
# Epoch:  3 , train: 0.15120849828601507 , valid: 0.13520309934392571
# Saving model...
# 	completed in 39.73511624336243 seconds
# Epoch 4/200:
# Epoch:  4 , train: 0.1356717145515778 , valid: 0.12430400587618351
# Saving model...
# 	completed in 39.92249059677124 seconds
# Epoch 5/200:
# Epoch:  5 , train: 0.12746875582305134 , valid: 0.12002602219581604
# Saving model...
# 	completed in 40.048272371292114 seconds
# Epoch 6/200:
# Epoch:  6 , train: 0.12128571245370735 , valid: 0.114498071372509
# Saving model...
# 	completed in 40.114455461502075 seconds
# Epoch 7/200:
# Epoch:  7 , train: 0.11623594006214674 , valid: 0.11050347331911325
# Saving model...
# 	completed in 40.13936471939087 seconds
# Epoch 8/200:
# Epoch:  8 , train: 0.11279866035644089 , valid: 0.10807793866842985
# Saving model...
# 	completed in 40.15705728530884 seconds
# Epoch 9/200:
# Epoch:  9 , train: 0.11121806006937127 , valid: 0.10614106291905046
# Saving model...
# 	completed in 40.21565794944763 seconds
# Epoch 10/200:
# Epoch:  10 , train: 0.10899755908712666 , valid: 0.10460355505347252
# Saving model...
# 	completed in 40.24743175506592 seconds
# Epoch 11/200:
# Epoch:  11 , train: 0.1076454840093383 , valid: 0.10326746292412281
# Saving model...
# 	completed in 41.315735816955566 seconds
# Epoch 12/200:
# Epoch:  12 , train: 0.10610820068270749 , valid: 0.10216392856091261
# Saving model...
# 	completed in 40.22349810600281 seconds
# Epoch 13/200:
# Epoch:  13 , train: 0.10503982928098808 , valid: 0.10151861468330026
# Saving model...
# 	completed in 40.232771158218384 seconds
# Epoch 14/200:
# Epoch:  14 , train: 0.10399113979067062 , valid: 0.10104764671996236
# Saving model...
# 	completed in 40.25903105735779 seconds
# Epoch 15/200:
# Epoch:  15 , train: 0.10318220335255535 , valid: 0.10019632382318377
# Saving model...
# 	completed in 40.24958539009094 seconds
# Epoch 16/200:
# Epoch:  16 , train: 0.10213921078680697 , valid: 0.09957041777670383
# Saving model...
# 	completed in 40.236875772476196 seconds
# Epoch 17/200:
# Epoch:  17 , train: 0.10169731639650688 , valid: 0.09887893963605165
# Saving model...
# 	completed in 40.29698634147644 seconds
# Epoch 18/200:
# Epoch:  18 , train: 0.10123559372275287 , valid: 0.09901888109743595
# 	completed in 40.08783316612244 seconds
# Epoch 19/200:
# Epoch:  19 , train: 0.10051897468523205 , valid: 0.09804404806345701
# Saving model...
# 	completed in 40.23904275894165 seconds
# Epoch 20/200:
# Epoch:  20 , train: 0.09991427425158586 , valid: 0.09689804958179593
# Saving model...
# 	completed in 40.239728689193726 seconds
# Epoch 21/200:
# Epoch:  21 , train: 0.09878821920662026 , valid: 0.09667392913252115
# Saving model...
# 	completed in 41.369630336761475 seconds
# Epoch 22/200:
# Epoch:  22 , train: 0.09808897777065556 , valid: 0.0981093910522759
# 	completed in 40.036932706832886 seconds
# Epoch 23/200:
# Epoch:  23 , train: 0.09855479349172552 , valid: 0.09752104338258505
# 	completed in 40.046332359313965 seconds
# Epoch 24/200:
# Epoch:  24 , train: 0.09861498089412953 , valid: 0.09870382864028215
# 	completed in 40.05262041091919 seconds
# Epoch 25/200:
# Epoch:  25 , train: 0.09840889106038145 , valid: 0.09848669404163957
# 	completed in 40.025651693344116 seconds
# Epoch 26/200:
# Epoch:  26 , train: 0.09863375812560891 , valid: 0.10066019976511598
# 	completed in 40.00292372703552 seconds
# Epoch 27/200:
# Epoch:  27 , train: 0.09821218309394145 , valid: 0.09820050979033113
# 	completed in 39.98367357254028 seconds
# Epoch 28/200:
# Epoch:  28 , train: 0.09610203078852066 , valid: 0.09747724374756217
# 	completed in 39.98435592651367 seconds
# Epoch 29/200:
# Epoch:  29 , train: 0.0945246593594343 , valid: 0.09670578269287944
# 	completed in 39.992713928222656 seconds
# Epoch 30/200:
# Epoch:  30 , train: 0.09457905095129113 , valid: 0.09550663735717535
# Saving model...
# 	completed in 40.129910707473755 seconds
# Epoch 31/200:
# Epoch:  31 , train: 0.09480695115698154 , valid: 0.09481238108128309
# Saving model...
# 	completed in 41.17314887046814 seconds
# Epoch 32/200:
# Epoch:  32 , train: 0.09423598647117615 , valid: 0.09650597209110856
# 	completed in 39.96664881706238 seconds
# Epoch 33/200:
# Epoch:  33 , train: 0.09474237135775634 , valid: 0.0938881984911859
# Saving model...
# 	completed in 40.133654832839966 seconds
# Epoch 34/200:
# Epoch:  34 , train: 0.09412559450816942 , valid: 0.09462445229291916
# 	completed in 40.00635886192322 seconds
# Epoch 35/200:
# Epoch:  35 , train: 0.0936185323729149 , valid: 0.09446063823997974
# 	completed in 39.994823932647705 seconds
# Epoch 36/200:
# Epoch:  36 , train: 0.09338297969279696 , valid: 0.0955319358035922
# 	completed in 39.99665284156799 seconds
# Epoch 37/200:
# Epoch:  37 , train: 0.09265212185459819 , valid: 0.09615931799635291
# 	completed in 39.980764865875244 seconds
# Epoch 38/200:
# Epoch:  38 , train: 0.0929394519479903 , valid: 0.09687233064323664
# 	completed in 39.972660303115845 seconds
# Epoch 39/200:
# Epoch:  39 , train: 0.09427392922250805 , valid: 0.10212748451158404
# 	completed in 39.999369859695435 seconds
# Epoch 40/200:
# Epoch:  40 , train: 0.09470653080139277 , valid: 0.10558617487549782
# 	completed in 39.99003601074219 seconds
# Epoch 41/200:
# Epoch:  41 , train: 0.09549614335906027 , valid: 0.10000566393136978
# 	completed in 41.12027406692505 seconds
# Epoch 42/200:
# Epoch:  42 , train: 0.0930083094857126 , valid: 0.0973647222854197
# 	completed in 39.98309588432312 seconds
# Epoch 43/200:
# Epoch:  43 , train: 0.09212920435072032 , valid: 0.0952201122418046
# 	completed in 40.03438711166382 seconds
# Epoch 44/200:
# Epoch:  44 , train: 0.09141268718981202 , valid: 0.09537381632253528
# 	completed in 40.05653977394104 seconds
# Epoch 45/200:
# Epoch:  45 , train: 0.0915304554486566 , valid: 0.09447008837014437
# 	completed in 40.046884059906006 seconds
# Epoch 46/200:
# Epoch:  46 , train: 0.09149189917516957 , valid: 0.09394256072118878
# 	completed in 40.04420495033264 seconds
# Epoch 47/200:
# Epoch:  47 , train: 0.09166710252953242 , valid: 0.09536228608340025
# 	completed in 40.047276735305786 seconds
# Epoch 48/200:
# Epoch:  48 , train: 0.09200927170471371 , valid: 0.09351542079821229
# Saving model...
# 	completed in 40.19200325012207 seconds
# Epoch 49/200:
# Epoch:  49 , train: 0.09118712403491322 , valid: 0.09372090268880129
# 	completed in 40.06648826599121 seconds
# Epoch 50/200:
# Epoch:  50 , train: 0.09002598481704635 , valid: 0.0930292489938438
# Saving model...
# 	completed in 40.22390079498291 seconds
# Epoch 51/200:
# Epoch:  51 , train: 0.09024498853539921 , valid: 0.09286083094775677
# Saving model...
# 	completed in 41.25446438789368 seconds
# Epoch 52/200:
# Epoch:  52 , train: 0.09043139211482402 , valid: 0.09296647738665342
# 	completed in 40.061137199401855 seconds
# Epoch 53/200:
# Epoch:  53 , train: 0.09050538904483822 , valid: 0.09522656444460154
# 	completed in 40.08012652397156 seconds
# Epoch 54/200:
# Epoch:  54 , train: 0.09109401355707208 , valid: 0.09318475285544991
# 	completed in 40.1143581867218 seconds
# Epoch 55/200:
# Epoch:  55 , train: 0.09105236319919323 , valid: 0.09339390369132161
# 	completed in 40.091721296310425 seconds
# Epoch 56/200:
# Epoch:  56 , train: 0.09005399314884949 , valid: 0.09220117423683405
# Saving model...
# 	completed in 40.263874769210815 seconds
# Epoch 57/200:
# Epoch:  57 , train: 0.08928052688352309 , valid: 0.09208807675167918
# Saving model...
# 	completed in 40.23245978355408 seconds
# Epoch 58/200:
# Epoch:  58 , train: 0.08938390873437568 , valid: 0.09319306164979935
# 	completed in 40.11242365837097 seconds
# Epoch 59/200:
# Epoch:  59 , train: 0.089793481608856 , valid: 0.09639895055443048
# 	completed in 40.128772258758545 seconds
# Epoch 60/200:
# Epoch:  60 , train: 0.08999571698290307 , valid: 0.09650333831086755
# 	completed in 40.14088225364685 seconds
# Epoch 61/200:
# Epoch:  61 , train: 0.08956048541408143 , valid: 0.09311310388147831
# 	completed in 41.38162565231323 seconds
# Epoch 62/200:
# Epoch:  62 , train: 0.08984003307047522 , valid: 0.09198334347456694
# Saving model...
# 	completed in 40.332096338272095 seconds
# Epoch 63/200:
# Epoch:  63 , train: 0.08998131345027821 , valid: 0.09112375183030963
# Saving model...
# 	completed in 40.30046725273132 seconds
# Epoch 64/200:
# Epoch:  64 , train: 0.08929095867156567 , valid: 0.09362534526735544
# 	completed in 40.15074634552002 seconds
# Epoch 65/200:
# Epoch:  65 , train: 0.0897579759775448 , valid: 0.09590870700776577
# 	completed in 40.15574312210083 seconds
# Epoch 66/200:
# Epoch:  66 , train: 0.08943646565001673 , valid: 0.09389710472896695
# 	completed in 40.14219284057617 seconds
# Epoch 67/200:
# Epoch:  67 , train: 0.08911998794913084 , valid: 0.0916516943834722
# 	completed in 40.170215129852295 seconds
# Epoch 68/200:
# Epoch:  68 , train: 0.08840387764453472 , valid: 0.09024819126352668
# Saving model...
# 	completed in 40.32476353645325 seconds
# Epoch 69/200:
# Epoch:  69 , train: 0.0880367322247898 , valid: 0.09048604732379317
# 	completed in 40.17218899726868 seconds
# Epoch 70/200:
# Epoch:  70 , train: 0.08810090631194556 , valid: 0.08987848460674286
# Saving model...
# 	completed in 40.35217881202698 seconds
# Epoch 71/200:
# Epoch:  71 , train: 0.08875993468894593 , valid: 0.0922428579069674
# 	completed in 41.197608947753906 seconds
# Epoch 72/200:
# Epoch:  72 , train: 0.08872226646485337 , valid: 0.09164125332608819
# 	completed in 40.18738770484924 seconds
# Epoch 73/200:
# Epoch:  73 , train: 0.08790096921446436 , valid: 0.09137756004929543
# 	completed in 40.20499062538147 seconds
# Epoch 74/200:
# Epoch:  74 , train: 0.08828298270338285 , valid: 0.09220227506011724
# 	completed in 40.186365604400635 seconds
# Epoch 75/200:
# Epoch:  75 , train: 0.08796730003015742 , valid: 0.09090058133006096
# 	completed in 40.180845975875854 seconds
# Epoch 76/200:
# Epoch:  76 , train: 0.0870743091323821 , valid: 0.09181393682956696
# 	completed in 40.1908061504364 seconds
# Epoch 77/200:
# Epoch:  77 , train: 0.08672137769104922 , valid: 0.09090674156323075
# 	completed in 40.212074995040894 seconds
# Epoch 78/200:
# Epoch:  78 , train: 0.08687086021088805 , valid: 0.09189747599884868
# 	completed in 40.208173990249634 seconds
# Epoch 79/200:
# Epoch:  79 , train: 0.08709003495452292 , valid: 0.091589180752635
# 	completed in 40.21188497543335 seconds
# Epoch 80/200:
# Epoch:  80 , train: 0.08792963637003308 , valid: 0.08947544079273939
# Saving model...
# 	completed in 40.3359272480011 seconds
# Epoch 81/200:
# Epoch:  81 , train: 0.087425371830272 , valid: 0.08963856613263488
# 	completed in 41.1570725440979 seconds
# Epoch 82/200:
# Epoch:  82 , train: 0.08752814913087283 , valid: 0.0908368555828929
# 	completed in 40.10624289512634 seconds
# Epoch 83/200:
# Epoch:  83 , train: 0.08734795651406727 , valid: 0.09032676136121154
# 	completed in 40.173383474349976 seconds
# Epoch 84/200:
# Epoch:  84 , train: 0.08656017227426666 , valid: 0.09213913744315505
# 	completed in 40.130452394485474 seconds
# Epoch 85/200:
# Epoch:  85 , train: 0.08693102995554607 , valid: 0.09303905721753836
# 	completed in 40.10645318031311 seconds
# Epoch 86/200:
# Epoch:  86 , train: 0.08704448033637817 , valid: 0.09067293163388968
# 	completed in 40.10661959648132 seconds
# Epoch 87/200:
# Epoch:  87 , train: 0.08665899475987669 , valid: 0.09063276508823037
# 	completed in 40.09334349632263 seconds
# Epoch 88/200:
# Epoch:  88 , train: 0.08640134927489995 , valid: 0.09047605376690626
# 	completed in 40.09024381637573 seconds
# Epoch 89/200:
# Epoch:  89 , train: 0.08644248203197283 , valid: 0.08981766598299146
# 	completed in 40.085712909698486 seconds
# Epoch 90/200:
# Epoch:  90 , train: 0.08605452195252007 , valid: 0.08985461434349418
# 	completed in 40.0909583568573 seconds
# Epoch 91/200:
# Epoch:  91 , train: 0.08682720950864789 , valid: 0.09089249605312943
# 	completed in 41.35610795021057 seconds
# Epoch 92/200:
# Epoch:  92 , train: 0.08629195988958419 , valid: 0.09008673531934619
# 	completed in 40.030935287475586 seconds
# Epoch 93/200:
# Epoch:  93 , train: 0.08561437000987002 , valid: 0.09010082576423883
# 	completed in 40.044692277908325 seconds
# Epoch 94/200:
# Epoch:  94 , train: 0.08585672643536256 , valid: 0.09199381712824106
# 	completed in 40.05787014961243 seconds
# Epoch 95/200:
# Epoch:  95 , train: 0.08666735527351056 , valid: 0.09023497439920902
# 	completed in 40.062140226364136 seconds
# Epoch 96/200:
# Epoch:  96 , train: 0.0864808031245676 , valid: 0.0903357439674437
# 	completed in 40.00413990020752 seconds
# Epoch 97/200:
# Epoch:  97 , train: 0.08635876477284789 , valid: 0.09198889508843422
# 	completed in 40.011470317840576 seconds
# Epoch 98/200:
# Epoch:  98 , train: 0.08604470395969055 , valid: 0.08930542506277561
# Saving model...
# 	completed in 40.14911937713623 seconds
# Epoch 99/200:
# Epoch:  99 , train: 0.08593237527481964 , valid: 0.09004362812265754
# 	completed in 39.975728273391724 seconds
# Epoch 100/200:
# Epoch:  100 , train: 0.08593405936608972 , valid: 0.09113457938656211
# 	completed in 39.988975524902344 seconds
# Epoch 101/200:
# Epoch:  101 , train: 0.08567517053134362 , valid: 0.09053660556674004
# 	completed in 40.98628282546997 seconds
# Epoch 102/200:
# Epoch:  102 , train: 0.08575596339207461 , valid: 0.08889930183067918
# Saving model...
# 	completed in 40.11432886123657 seconds
# Epoch 103/200:
# Epoch:  103 , train: 0.0855692282423091 , valid: 0.08961354196071625
# 	completed in 39.975669860839844 seconds
# Epoch 104/200:
# Epoch:  104 , train: 0.08533135792451796 , valid: 0.09088317072018981
# 	completed in 39.99266338348389 seconds
# Epoch 105/200:
# Epoch:  105 , train: 0.0848068444100558 , valid: 0.09017093246802688
# 	completed in 39.99859023094177 seconds
# Epoch 106/200:
# Epoch:  106 , train: 0.08502658972773461 , valid: 0.09047010680660605
# 	completed in 39.983646392822266 seconds
# Epoch 107/200:
# Epoch:  107 , train: 0.08525352308731429 , valid: 0.09035311779007316
# 	completed in 40.01050090789795 seconds
# Epoch 108/200:
# Epoch:  108 , train: 0.08574150949976624 , valid: 0.08941712277010083
# 	completed in 40.01142072677612 seconds
# Epoch 109/200:
# Epoch:  109 , train: 0.08538394010451868 , valid: 0.08850338915362954
# Saving model...
# 	completed in 40.15603184700012 seconds
# Epoch 110/200:
# Epoch:  110 , train: 0.08454355008471075 , valid: 0.09007523814216256
# 	completed in 40.0200879573822 seconds
# Epoch 111/200:
# Epoch:  111 , train: 0.08472007480539369 , valid: 0.09045867156237364
# 	completed in 41.03026556968689 seconds
# Epoch 112/200:
# Epoch:  112 , train: 0.08559504446506916 , valid: 0.0921707209199667
# 	completed in 39.9837601184845 seconds
# Epoch 113/200:
# Epoch:  113 , train: 0.08591757657536245 , valid: 0.09145773528143764
# 	completed in 40.04836869239807 seconds
# Epoch 114/200:
# Epoch:  114 , train: 0.08665241951197646 , valid: 0.09120426559820771
# 	completed in 40.041935443878174 seconds
# Epoch 115/200:
# Epoch:  115 , train: 0.08666886715624761 , valid: 0.08975539077073336
# 	completed in 40.02872657775879 seconds
# Epoch 116/200:
# Epoch:  116 , train: 0.0863728605431828 , valid: 0.08978982269763947
# 	completed in 40.040794134140015 seconds
# Epoch 117/200:
# Epoch:  117 , train: 0.08481318069326108 , valid: 0.09212798764929175
# 	completed in 40.04845952987671 seconds
# Epoch 118/200:
# Epoch:  118 , train: 0.0846638991700625 , valid: 0.08924990938976407
# 	completed in 40.05846643447876 seconds
# Epoch 119/200:
# Epoch:  119 , train: 0.08441887773170313 , valid: 0.09000927768647671
# 	completed in 40.04440665245056 seconds
# Epoch 120/200:
# Epoch:  120 , train: 0.08492362810002987 , valid: 0.08969257492572069
# 	completed in 40.04942774772644 seconds
# Epoch 121/200:
# Epoch:  121 , train: 0.08518961636287796 , valid: 0.08891048654913902
# 	completed in 41.0858211517334 seconds
# Epoch 122/200:
# Epoch:  122 , train: 0.08611955569104582 , valid: 0.09197121998295188
# 	completed in 40.043521881103516 seconds
# Epoch 123/200:
# Epoch:  123 , train: 0.08581399298671237 , valid: 0.09178052190691233
# 	completed in 40.03928351402283 seconds
# Epoch 124/200:
# Epoch:  124 , train: 0.08582364147558262 , valid: 0.09267355455085635
# 	completed in 40.05505847930908 seconds
# Epoch 125/200:
# Epoch:  125 , train: 0.08528652209886081 , valid: 0.09194720163941383
# 	completed in 40.0756311416626 seconds
# Epoch 126/200:
# Epoch:  126 , train: 0.08544081599040389 , valid: 0.09183705179020762
# 	completed in 40.081685066223145 seconds
# Epoch 127/200:
# Epoch:  127 , train: 0.08523242071557004 , valid: 0.09206671873107553
# 	completed in 40.106584310531616 seconds
# Epoch 128/200:
# Epoch:  128 , train: 0.08506813594652096 , valid: 0.08997711492702365
# 	completed in 40.10780358314514 seconds
# Epoch 129/200:
# Epoch:  129 , train: 0.08555040555318613 , valid: 0.09002013551071286
# 	completed in 40.163344860076904 seconds
# Epoch 130/200:
# Epoch:  130 , train: 0.0855158202701214 , valid: 0.09019239339977503
# 	completed in 40.11049747467041 seconds
# Epoch 131/200:
# Epoch:  131 , train: 0.08627849083920423 , valid: 0.09114972362294793
# 	completed in 41.4746789932251 seconds
# Epoch 132/200:
# Epoch:  132 , train: 0.08710085479688894 , valid: 0.0929568987339735
# 	completed in 40.082759380340576 seconds
# Epoch 133/200:
# Epoch:  133 , train: 0.08741112473383415 , valid: 0.09189948718994856
# 	completed in 40.10162162780762 seconds
# Epoch 134/200:
# Epoch:  134 , train: 0.0866719895216391 , valid: 0.09291745582595468
# 	completed in 40.10738182067871 seconds
# Epoch 135/200:
# Epoch:  135 , train: 0.08547146735391067 , valid: 0.09157735947519541
# 	completed in 40.10290575027466 seconds
# Epoch 136/200:
# Epoch:  136 , train: 0.08492082373009927 , valid: 0.09152638399973512
# 	completed in 40.11463809013367 seconds
# Epoch 137/200:
# Epoch:  137 , train: 0.08447051994879624 , valid: 0.09084416693076491
# 	completed in 40.124255657196045 seconds
# Epoch 138/200:
# Epoch:  138 , train: 0.08422174671401528 , valid: 0.09083967050537467
# 	completed in 40.106258153915405 seconds
# Epoch 139/200:
# Epoch:  139 , train: 0.08390260247243844 , valid: 0.09042174322530627
# 	completed in 40.1179461479187 seconds
# Epoch 140/200:
# Epoch:  140 , train: 0.08418266362076654 , valid: 0.09180444851517677
# 	completed in 40.10444617271423 seconds
# Epoch 141/200:
# Epoch:  141 , train: 0.0846443982960666 , valid: 0.09206427820026875
# 	completed in 41.128504276275635 seconds
# Epoch 142/200:
# Epoch:  142 , train: 0.08498242410325671 , valid: 0.09182266611605883
# 	completed in 40.09506344795227 seconds
# Epoch 143/200:
# Epoch:  143 , train: 0.08525330642235009 , valid: 0.09249112289398909
# 	completed in 40.112762451171875 seconds
# Epoch 144/200:
# Epoch:  144 , train: 0.08448408735204117 , valid: 0.09170560212805867
# 	completed in 40.1098575592041 seconds
# Epoch 145/200:
# Epoch:  145 , train: 0.08440708157071684 , valid: 0.09167928341776133
# 	completed in 40.15641975402832 seconds
# Epoch 146/200:
# Epoch:  146 , train: 0.0847259900462773 , valid: 0.08920350158587098
# 	completed in 40.09814262390137 seconds
# Epoch 147/200:
# Epoch:  147 , train: 0.08504111683857586 , valid: 0.08923696260899305
# 	completed in 40.088770389556885 seconds
# Epoch 148/200:
# Epoch:  148 , train: 0.08539130081004913 , valid: 0.09194517694413662
# 	completed in 40.107258319854736 seconds
# Epoch 149/200:
# Epoch:  149 , train: 0.08515520499170763 , valid: 0.0944134914316237
# 	completed in 40.156445026397705 seconds
# Epoch 150/200:
# Epoch:  150 , train: 0.08470173073480683 , valid: 0.09195060562342405
# 	completed in 40.11826491355896 seconds
# Epoch 151/200:
# Epoch:  151 , train: 0.08410897907552295 , valid: 0.09212411567568779
# 	completed in 41.15033745765686 seconds
# Epoch 152/200:
# Epoch:  152 , train: 0.08421002675569494 , valid: 0.09047716856002808
# 	completed in 40.07172131538391 seconds
# Epoch 153/200:
# Epoch:  153 , train: 0.08455198776971608 , valid: 0.08947502169758081
# 	completed in 40.057371377944946 seconds
# Epoch 154/200:
# Epoch:  154 , train: 0.0839041914485304 , valid: 0.08850946417078376
# 	completed in 40.06858515739441 seconds
# Epoch 155/200:
# Epoch:  155 , train: 0.08389820216994011 , valid: 0.08869392750784755
# 	completed in 40.12565732002258 seconds
# Epoch 156/200:
# Epoch:  156 , train: 0.0838489456144511 , valid: 0.08944710902869701
# 	completed in 40.09971594810486 seconds
# Epoch 157/200:
# Epoch:  157 , train: 0.08503465089186324 , valid: 0.08951853169128299
# 	completed in 40.09223246574402 seconds
# Epoch 158/200:
# Epoch:  158 , train: 0.08625058916902875 , valid: 0.09170461818575859
# 	completed in 40.065595865249634 seconds
# Epoch 159/200:
# Epoch:  159 , train: 0.08488608154274822 , valid: 0.09046604204922915
# 	completed in 40.04239463806152 seconds
# Epoch 160/200:
# Epoch:  160 , train: 0.08333727305212155 , valid: 0.08930539665743709
# 	completed in 39.98717403411865 seconds
# Epoch 161/200:
# Epoch:  161 , train: 0.08316667717970895 , valid: 0.09169579343870282
# 	completed in 41.02741193771362 seconds
# Epoch 162/200:
# Epoch:  162 , train: 0.08339471951205069 , valid: 0.09391042497009039
# 	completed in 39.97678065299988 seconds
# Epoch 163/200:
# Epoch:  163 , train: 0.0854313222928717 , valid: 0.09208326181396842
# 	completed in 39.970954179763794 seconds
# Epoch 164/200:
# Epoch:  164 , train: 0.08489315462726157 , valid: 0.09258612245321274
# 	completed in 39.9944269657135 seconds
# Epoch 165/200:
# Epoch:  165 , train: 0.08472251876486533 , valid: 0.09337192494422197
# 	completed in 39.999829053878784 seconds
# Epoch 166/200:
# Epoch:  166 , train: 0.0846118124471701 , valid: 0.09147875942289829
# 	completed in 39.99933385848999 seconds
# Epoch 167/200:
# Epoch:  167 , train: 0.08325199630716085 , valid: 0.08910673251375556
# 	completed in 40.00372314453125 seconds
# Epoch 168/200:
# Epoch:  168 , train: 0.0825205366037799 , valid: 0.0895178047940135
# 	completed in 39.97837424278259 seconds
# Epoch 169/200:
# Epoch:  169 , train: 0.08238547025524717 , valid: 0.08943688310682774
# 	completed in 39.9773063659668 seconds
# Epoch 170/200:
# Epoch:  170 , train: 0.08269466355078924 , valid: 0.0895564123056829
# 	completed in 39.98467183113098 seconds
# Epoch 171/200:
# Epoch:  171 , train: 0.08292148574978685 , valid: 0.08941996470093727
# 	completed in 41.02036643028259 seconds
# Epoch 172/200:
# Epoch:  172 , train: 0.0833313392563016 , valid: 0.09142465004697442
# 	completed in 39.95432186126709 seconds
# Epoch 173/200:
# Epoch:  173 , train: 0.0835345221023493 , valid: 0.0906079662963748
# 	completed in 39.9796097278595 seconds
# Epoch 174/200:
# Epoch:  174 , train: 0.08362975305053576 , valid: 0.0960879591293633
# 	completed in 39.981637716293335 seconds
# Epoch 175/200:
# Epoch:  175 , train: 0.08433574300915991 , valid: 0.09541853051632643
# 	completed in 40.00799608230591 seconds
# Epoch 176/200:
# Epoch:  176 , train: 0.08339254017821782 , valid: 0.09111848147585988
# 	completed in 40.00446891784668 seconds
# Epoch 177/200:
# Epoch:  177 , train: 0.08269021423439289 , valid: 0.09023463306948543
# 	completed in 40.02567958831787 seconds
# Epoch 178/200:
# Epoch:  178 , train: 0.08291555204498623 , valid: 0.09019212145358324
# 	completed in 40.02572011947632 seconds
# Epoch 179/200:
# Epoch:  179 , train: 0.0828948418624426 , valid: 0.08878359524533153
# 	completed in 40.01730942726135 seconds
# Epoch 180/200:
# Epoch:  180 , train: 0.0835804739742691 , valid: 0.08868824550881982
# 	completed in 40.008198499679565 seconds
# Epoch 181/200:
# Epoch:  181 , train: 0.08338963371712917 , valid: 0.08783324901014566
# Saving model...
# 	completed in 41.549344062805176 seconds
# Epoch 182/200:
# Epoch:  182 , train: 0.08360566602561487 , valid: 0.08774913940578699
# Saving model...
# 	completed in 40.17146277427673 seconds
# Epoch 183/200:
# Epoch:  183 , train: 0.08293464309153964 , valid: 0.0915893311612308
# 	completed in 40.031455278396606 seconds
# Epoch 184/200:
# Epoch:  184 , train: 0.08285918337720435 , valid: 0.09631180390715599
# 	completed in 40.063987016677856 seconds
# Epoch 185/200:
# Epoch:  185 , train: 0.08289510115695041 , valid: 0.09590644761919975
# 	completed in 40.095101833343506 seconds
# Epoch 186/200:
# Epoch:  186 , train: 0.0830719918922812 , valid: 0.09136044699698687
# 	completed in 40.07779574394226 seconds
# Epoch 187/200:
# Epoch:  187 , train: 0.08333100456529886 , valid: 0.08988608978688717
# 	completed in 40.10443925857544 seconds
# Epoch 188/200:
# Epoch:  188 , train: 0.08471830187927783 , valid: 0.08939469931647182
# 	completed in 40.06650471687317 seconds
# Epoch 189/200:
# Epoch:  189 , train: 0.08481271302304759 , valid: 0.09031927725300193
# 	completed in 40.07589840888977 seconds
# Epoch 190/200:
# Epoch:  190 , train: 0.08428250764208939 , valid: 0.09028343949466944
# 	completed in 40.052693128585815 seconds
# Epoch 191/200:
# Epoch:  191 , train: 0.08448976021500575 , valid: 0.0898389439098537
# 	completed in 41.10562562942505 seconds
# Epoch 192/200:
# Epoch:  192 , train: 0.08436628578012942 , valid: 0.09029721794649959
# 	completed in 40.06350517272949 seconds
# Epoch 193/200:
# Epoch:  193 , train: 0.08408264689680585 , valid: 0.08850545575842261
# 	completed in 40.08791160583496 seconds
# Epoch 194/200:
# Epoch:  194 , train: 0.08364385671354505 , valid: 0.08846774091944098
# 	completed in 40.11955904960632 seconds
# Epoch 195/200:
# Epoch:  195 , train: 0.08336813835001325 , valid: 0.0880071371793747
# 	completed in 40.13524675369263 seconds
# Epoch 196/200:
# Epoch:  196 , train: 0.08327490078321094 , valid: 0.08802301995456219
# 	completed in 40.10345530509949 seconds
# Epoch 197/200:
# Epoch:  197 , train: 0.08366224455791826 , valid: 0.08988239103928208
# 	completed in 40.12852716445923 seconds
# Epoch 198/200:
# Epoch:  198 , train: 0.08381125829580775 , valid: 0.09011481376364827
# 	completed in 40.14335608482361 seconds
# Epoch 199/200:
# Epoch:  199 , train: 0.08405764321642188 , valid: 0.08994630957022309
# 	completed in 40.11392569541931 seconds
# Epoch 200/200:
# Epoch:  200 , train: 0.08358632639232522 , valid: 0.09153666906058788
# 	completed in 40.12555384635925 seconds
# Training complete in 133m 59s
# Saving model...

# %% [markdown]
# **The export function saves all of the deformation fields for the validation and test cases**

# %%
lrnr.export()
# Out:
# Testing batch 1 of 17 | Loss: 0.08097555488348007
# Testing batch 2 of 17 | Loss: 0.05820991471409798
# Testing batch 3 of 17 | Loss: 0.11537837237119675
# Testing batch 4 of 17 | Loss: 0.085333913564682
# Testing batch 5 of 17 | Loss: 0.07869431376457214
# Testing batch 6 of 17 | Loss: 0.06893381476402283
# Testing batch 7 of 17 | Loss: 0.07939430326223373
# Testing batch 8 of 17 | Loss: 0.10139989852905273
# Testing batch 9 of 17 | Loss: 0.0667744129896164
# Testing batch 10 of 17 | Loss: 0.0687669962644577
# Testing batch 11 of 17 | Loss: 0.07163462787866592
# Testing batch 12 of 17 | Loss: 0.073055200278759
# Testing batch 13 of 17 | Loss: 0.05270542949438095
# Testing batch 14 of 17 | Loss: 0.08755021542310715
# Testing batch 15 of 17 | Loss: 0.07383257150650024
# Testing batch 16 of 17 | Loss: 0.07630957663059235
# Testing batch 17 of 17 | Loss: 0.10559100657701492

# %% [markdown]
# **The evaluate function finds the Dice score and 95th Percentile Hausdorff distance (95HD) of each case, saving the results in pickled dictionary for later reference**

# %%
lrnr.evaluate()

# %% [markdown]
# # Plot the results

# %%
with open(os.path.join(lrnr.progress_dir, "results.pkl"), "rb") as file:
    results = pickle.load(file)

def noble_boxplot(D):
    bp = plt.boxplot(D, widths=0.35)
    sf = .1 * (1 - np.exp(-np.shape(D)[1] / 4))
    d_bin = np.zeros(np.shape(D)[0], dtype=int)
    for i in range(0, np.shape(D)[1]):
        h, x = np.histogram(D[:, i])
        h = h / np.amax(h)
        for j in range(0, np.shape(D)[0]):
            bin = np.nonzero(D[j, i] < x)
            if np.size(bin) > 0:
                d_bin[j] = bin[0][0] - 1
            else:
                d_bin[j] = np.size(x) - 2
        dx = np.random.default_rng(0).normal(size=np.shape(D)[0]) * sf * h[d_bin]
        msk = np.abs(dx) > sf * 2
        dx[msk] = 2 * sf * dx[msk] / np.abs(dx[msk])
        plt.plot(dx + i + 1, D, '.', color="purple", alpha=.25)
        
plt.figure(figsize = (4, 6))
plt.subplot(121)
plt.title("95HD")
noble_boxplot(np.expand_dims(results['test']['dist_95s'], axis = 1))
plt.ylabel("mm")
plt.gca().axes.get_xaxis().set_visible(False)

plt.subplot(122)
plt.title("Dice")
noble_boxplot(np.expand_dims(results['test']['dice_scores'], axis = 1))
plt.ylabel("Score")
plt.gca().axes.get_xaxis().set_visible(False)

plt.tight_layout()
plt.show()
